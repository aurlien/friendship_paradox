# %% [markdown]
# # Spark
#
# [Spark](https://spark.apache.org/docs/1.6.2/index.html) (we are going to use version 1.6.2) is a fast and general-purpose cluster computing system, that allows to process large datasets using several machines. In the era of the *big data*, it has become a necessity to be able to distribute computing power and process data in parallel. We introduce here the basics of the framework.
#
# In any case, you should have a look at the [official tutorial](https://spark.apache.org/docs/1.6.2/programming-guide.html).

# %% [markdown]
# ## Hadoop File System (HDFS)
#
# The main abstraction Spark offers is the *Resisilient Distributed Dataset* (RDD), which is a collection of elements distributed across the nodes of the cluster. The idea is that you typically **do not** load them in the memory, but rather process them *lazily*. They are initialized with files in the *Hadoop File System* (HDFS).
#
# Let us first see what there is in HDFS.

# %%
# !hdfs dfs -ls
# Out:
# Found 1 items
# drwxr-xr-x   - paluchow hadoop          0 2017-02-22 09:41 .sparkStaging

# %% [markdown]
# *Note:* a line starting with `!` indicates a shell command. You can hence run this same command in a bash terminal.

# %% [markdown]
# We can now add a dataset to HFDS. In the `data` folder, there is text file containing 30000 tweets collected from the [Inauguration Day](https://en.wikipedia.org/wiki/United_States_presidential_inauguration) on January 20, 2017.

# %%
# !hdfs dfs -put data/election-day-tweets.txt

# %% [markdown]
# And check that the file is indeed in HDFS.

# %%
# !hdfs dfs -ls
# Out:
# Found 2 items
# drwxr-xr-x   - paluchow hadoop          0 2017-02-22 09:41 .sparkStaging
# -rw-r--r--   3 paluchow hadoop    2147813 2017-02-25 20:34 election-day-tweets.txt

# %% [markdown]
# *Note:* you can remove files from HDFS using `hdfs dfs -rm FILE`.

# %% [markdown]
# ## Dataset processing
#
# We can now start playing with the tweets. We will instantiate the dataset from the text file.

# %%
tweets = sc.textFile('election-day-tweets.txt')

# %% [markdown]
# The `tweets` variable is now an RDD. An RDD is *resilient* to faults by storing the sequence of operations applied to it so that it can easily recreate the state of the data structure in case of a problem. It can also be logically cut to be *distributed* on several machines.
#
# The `sc` object is a special object, namely a [Spark Context](https://spark.apache.org/docs/1.6.2/api/python/pyspark.html#pyspark.SparkContext) obeject, that we configured to be available everywhere in your Python environment. It is the main interface with Spark that has numerous useful methods. Check the documentation!
#
# Let us display a few tweets.

# %%
some_tweets = tweets.take(10)
for i, tweet in enumerate(some_tweets):
    print("%d: %s" % (i, tweet))
# Out:
# 0: @Lawrence @HillaryClinton Two first  @SenSchumer tomorrow. @TheLastWord #brooklyn  TheRealAmerica #Vote #Democrats #NastyWomenVote #Senate
# 1: My @latimesopinion op-ed on historic #California #Senate race. First time an elected woman senator succeeds another.
# 2: https://t.co/cbjQTK0Q1V
# 3: #Senate Wisconsin Senate Preview: Johnson vs. Feingold
# 4: If Rubio Wins and #Trump Loses in #Florida... #HillaryClinton #Senate #RepublicanPrimary #Senaterace #Miami... https://t.co/zIeNEcVnMO
# 5: #Senate Wisconsin Senate Preview: Johnson vs. Feingold
# 6: bob day is an honest  person   #senate patterson . a loss to the senate
# 7: Make Republicans #PayAPrice!
# 8:  💙🇺🇸#VoteBLUE🔃theBallot🇺🇸💙
# 9:  #Congress #Senate #FlipItDem

# %% [markdown]
# Once created, the `tweets` dataset can be acted on by dataset **operations**. RDDs support two types of operations: *transformations*, which create a new RDD from an existing one, and *actions*, which return a value to the driver program after running a computation on the RDD. For instance, we can `count` the number of tweets. Is it a transofrmation or an action?

# %%
tweets.count()
# Out:
# 30000

# %% [markdown]
# We can also `filter` the lines matching a specific string. Is it a transformation or an action ?
#
# *Note*: `lower()` is a `str` method that converts the string to lower case. What happens if you do not do that?

# %%
lines_with_trump = tweets.filter(lambda line: "trump" in line.lower())
lines_with_trump.count()
# Out:
# 1023

# %% [markdown]
# A typical processing pattern is [MapReduce](https://en.wikipedia.org/wiki/MapReduce), as popularized by Hadoop. The idea is that you apply a function to your dataset that filters or sorts it (**map**), and then combine the ouputs by computing something (**reduce**). The typical example is a word count. So, how many times each word occur among our tweets?

# %%
# Split every line into words and flattens the result (aggregate them all together)
words = tweets.flatMap(lambda line: line.split())
words.take(15)
# Out:
# ['@Lawrence',
#  '@HillaryClinton',
#  'Two',
#  'first',
#  '@SenSchumer',
#  'tomorrow.',
#  '@TheLastWord',
#  '#brooklyn',
#  'TheRealAmerica',
#  '#Vote',
#  '#Democrats',
#  '#NastyWomenVote',
#  '#Senate',
#  'My',
#  '@latimesopinion']

# %%
# Assign 1 to each word
counts = words.map(lambda word: (word, 1))
counts.take(10)
# Out:
# [('@Lawrence', 1),
#  ('@HillaryClinton', 1),
#  ('Two', 1),
#  ('first', 1),
#  ('@SenSchumer', 1),
#  ('tomorrow.', 1),
#  ('@TheLastWord', 1),
#  ('#brooklyn', 1),
#  ('TheRealAmerica', 1),
#  ('#Vote', 1)]

# %%
# Combines the counts by adding up the value (1) of equal keys (words)
word_counts = counts.reduceByKey(lambda a, b: a + b)
word_counts.take(10)
# Out:
# [('https://t.co/3Eq1y14Gjr', 1),
#  ('Gujarati', 2),
#  ('@ptshrikant', 3),
#  ('officials…', 1),
#  ('@YourDreaDose', 1),
#  ('#CLAD2016', 1),
#  ('.@gastropoda', 1),
#  ('Just', 130),
#  ('BSP', 37),
#  ('lagayye', 1)]

# %% [markdown]
# You should read the list of common [transformations](https://spark.apache.org/docs/1.6.2/programming-guide.html#transformations) and [actions](https://spark.apache.org/docs/1.6.2/programming-guide.html#actions) to get an idea of what you can do.

# %% [markdown]
# ## Dataset statistics
#
# Your turn! Try to extract some statisctis from the dataset:
#
# 1. Total number of words
# 2. Average number of words per tweet
# 3. Ten most frequent word

# %%
# Your code goes here
counts = words.map(lambda word: (word, 1))
word_counts = counts.reduceByKey(lambda a, b: a + b)
word_counts.collect()
# Out:
# [('https://t.co/3Eq1y14Gjr', 1),
#  ('Gujarati', 2),
#  ('@ptshrikant', 3),
#  ('officials…', 1),
#  ('@YourDreaDose', 1),
#  ('#CLAD2016', 1),
#  ('.@gastropoda', 1),
#  ('Just', 130),
#  ('BSP', 37),
#  ('lagayye', 1),
#  ('vez', 1),
#  ('Wordup.', 1),
#  ('#UseThe19th.', 1),
#  ('Trusting', 1),
#  ('Indictment', 1),
#  ('https://t.co/VpF2HevNvO)', 1),
#  ('https://t.co/K9HE7b5hNF', 1),
#  ('@robert_pohlman', 1),
#  ('@RahulGandi1', 3),
#  ("#BlackMoney.They're", 1),
#  ('options?', 1),
#  ('https://t.co/BEJsTUmlb3', 1),
#  ('@nypost', 1),
#  ('https://t.co/hJKhnzeIju', 1),
#  ('#logistics', 1),
#  ('graphics!', 1),
#  ('wholeheartedly', 1),
#  ('Things…', 1),
#  ('why', 272),
#  ('https://t.co/4ke1R5HXVE', 1),
#  ('FLINT', 1),
#  ('circle', 3),
#  ('gustado', 1),
#  ('hateful', 3),
#  ('passe', 1),
#  ('gerrymandering…', 1),
#  ('https://t.co/vtgbwREax8', 1),
#  ('🤗🤗🤗', 1),
#  ('untimely', 4),
#  ('https://t.co/7SL6hWi7Q8', 1),
#  ('#GOPcongress', 1),
#  ('@Eboracensis', 2),
#  ('@SirPuffAlot_JLR', 1),
#  ('BSP-Congress', 2),
#  ('.@NancyAFrench', 1),
#  ('CITIZENS...WORK', 1),
#  ('REP', 2),
#  ('#cartoons', 1),
#  ('#NV03', 2),
#  ('#ConservativeRead', 1),
#  ('(@DrBhava):', 1),
#  ('@rpcrd3', 1),
#  ('censors.', 1),
#  ('https://t.co/v69kE0vUQ6', 1),
#  ('China.', 2),
#  ('https://t.co/66NaioUVVy', 1),
#  ('https://t.co/N5qB1UQyDr…', 1),
#  ('Buy', 4),
#  ('muslims.', 1),
#  ('korte', 1),
#  ("Harris's", 3),
#  ('https://t.co/Jn8l7j9xTr', 1),
#  ('wants..', 1),
#  ('brothers..AAP', 1),
#  ('@MMJHealthcare', 1),
#  ('EXPLAIN', 1),
#  ('vote.', 48),
#  ('Kyo', 1),
#  ('lik...', 1),
#  ('payment.', 1),
#  ('https://t.co/VyU6I2jxuc', 1),
#  ('https://t.co/7hjMfWJiUT', 1),
#  ('promotes', 2),
#  ('immigration', 4),
#  ('https://t.co/imODbdliS1', 1),
#  ('Fiasco', 1),
#  ('BIO', 6),
#  ('Obama', 252),
#  ('https://t.co/b61TSvrLXQ', 1),
#  ('aoukat', 1),
#  ("'Death", 1),
#  ('@hfa', 1),
#  ('#Asian', 1),
#  ('lmaoo', 2),
#  ('https://t.co/wZj7txE9QE', 1),
#  ('Lawyers', 1),
#  ('ajluud', 1),
#  ('intimate.', 1),
#  ('https://t.co/JUnMMWUZD0', 1),
#  ('blackmail', 2),
#  ('plea', 2),
#  ('hybrid', 1),
#  ('10000…', 1),
#  ('year-', 1),
#  ('rubbishing', 1),
#  ('machine', 6),
#  ('elevated', 4),
#  ('Didi..', 1),
#  ('Days', 2),
#  ('HAHAHAAHAHAHAH', 1),
#  ('Exposing', 1),
#  ('Interpretation', 2),
#  ('https://t.co/63E5ELTCHX', 1),
#  ('news?', 1),
#  ('#congress...', 1),
#  ('@jgopikrishnan70', 1),
#  ('https://t.co/EOHnkYpAvW', 1),
#  ('looks', 21),
#  ('election(', 1),
#  ('Gब्बR', 1),
#  ('@RiversEdgePGH', 2),
#  ('https://t.co/OLLM53Hu1C', 1),
#  ('https://t.co/OPhvetxlNK', 1),
#  ('@Energy_Mex', 1),
#  ('GROW', 2),
#  ('https://t.co/kN3CryeE3C', 1),
#  ('BJP!!!!!', 1),
#  ('minor.', 1),
#  ('आसान', 1),
#  ('@guacamolly55', 1),
#  ('Loretta', 8),
#  ('Email', 4),
#  ('#chaos', 1),
#  ('https://t.co/7si7Gb4cR5', 1),
#  ('honesty', 7),
#  ('@toomuchpete', 1),
#  ('मे500-1000', 1),
#  ('boloh', 1),
#  ('choose!', 1),
#  ('suji', 2),
#  ("Saturday's", 1),
#  ('#progress', 2),
#  ('लगातार', 1),
#  ('Not=', 2),
#  ('#Reynolds4rep', 1),
#  ("car's", 1),
#  ('https://t.co/GZ0dJRvoaY', 1),
#  ('prince', 4),
#  ('Diggi', 1),
#  ('@ErinMayeQuade!', 1),
#  ('starring', 1),
#  ('https://t.co/AKvxZ27hmA', 1),
#  ('L.', 1),
#  ('https://t.co/eeYnuyHz9W', 1),
#  ('केलत', 1),
#  ('designed', 2),
#  ('foolis', 1),
#  ('https://t.co/9X0GQY5Brl', 1),
#  ('Body', 2),
#  ('https://t.co/BjLhz1a3CX', 1),
#  ('money...', 7),
#  ('here:', 4),
#  ('KYONKI', 1),
#  ('@KendallMigues', 1),
#  ('Singles', 1),
#  ('Rica', 1),
#  ('https://t.co/0ll2ZpBzYm', 1),
#  ('stampede', 1),
#  ('tips', 1),
#  ('https://t.co/QMZLafjo4L', 1),
#  ('free-market', 1),
#  ('#9thAmendment1st', 1),
#  ('lady', 5),
#  ('सारी', 3),
#  ('Rs.1000/500', 1),
#  ('fulfilled', 1),
#  ('clintons', 1),
#  ('soorajwala', 1),
#  ('https://t.co/0DHywDvCXd', 1),
#  ('statesman', 1),
#  ('Sonia', 71),
#  ('https://t.co/6HxCsusIcZ', 1),
#  ('RIP-Terrorist', 1),
#  ('@banditref', 1),
#  ('#BluehandFamily', 2),
#  ('GETS', 1),
#  ('Fin', 2),
#  ('@superinsane1988', 1),
#  ('shahdol', 2),
#  ('NOW!!!', 11),
#  ('ideologues', 1),
#  ('женщина...', 1),
#  ('https://t.co/A3OgC9SpPZ', 1),
#  ('@Althios', 1),
#  ('LDF', 1),
#  ('https://t.co/UMcUJxntlQ', 1),
#  ('ela', 2),
#  ('vasectomy', 1),
#  ('killing', 7),
#  ('https://t.co/83HLsKY9sl', 1),
#  ('https://t.co/njDmeo5IPd', 1),
#  ('#President...', 4),
#  ('terse', 1),
#  ('på', 1),
#  ('karogee......', 1),
#  ('Add', 2),
#  ('an', 316),
#  ('責任逃れする、（～に）責任転嫁する', 1),
#  ('Jaddu', 1),
#  ('https://t.co/WwdKKg3sPy', 2),
#  ('https://t.co/I4Y29En7Ly', 1),
#  ('@granmary7235', 3),
#  ('Hayden', 3),
#  ('#skincare', 1),
#  ('https://t.co/LHyvFoEadC', 1),
#  ('@SenatorCardin', 1),
#  ('@MorningBlend969', 2),
#  ('implanted', 1),
#  ('NGA', 1),
#  ('F-22', 1),
#  ('argued', 1),
#  ('bhokh', 1),
#  ('https://t.co/7LXhKrJWVV', 1),
#  ('Bingo.', 1),
#  ('jeebh', 1),
#  ('prominent', 2),
#  ('CCB', 2),
#  ('upadhya', 1),
#  ('https://t.co/mNtoTdgMJB', 1),
#  ('#CleanCongress', 1),
#  ('if...', 2),
#  ('25paise', 7),
#  ('uncont', 1),
#  ('Gandhiji', 2),
#  ('deliberately', 3),
#  ('Artery', 7),
#  ('fwd', 1),
#  ('https://t.co/N7ZdQdZZVW', 1),
#  ('😀😀😀', 2),
#  ('FACT:', 1),
#  ('https://t.co/lcV5eOVfPi', 1),
#  ('yeah...', 1),
#  ('https://t.co/hlQNXuZOxj', 1),
#  ('https://t.co/zRVzTnRnSR', 1),
#  ('Tamil', 4),
#  ('Jim', 4),
#  ('https://t.co/7dbOU3AQZs', 1),
#  ('https://t.co/6nvj1ZJ5aV', 1),
#  ('here...', 2),
#  ('https://t.co/o0yy54HD97', 1),
#  ('Republcian', 1),
#  ('Dubai', 4),
#  ('#browngirls', 1),
#  ('Congress?...', 1),
#  ('voto', 1),
#  ('us?', 7),
#  ('badi', 11),
#  ('Lo....', 1),
#  ('1ST', 1),
#  ('पड़े', 1),
#  ('@BobMorris25', 3),
#  ('reps/congress', 1),
#  ('IRON', 4),
#  ('LMB', 1),
#  ('Art', 1),
#  ('for!', 2),
#  ('Let…', 1),
#  ('https://t.co/NAmT6G8dU8', 1),
#  ('Murdoch', 1),
#  ('#TeluguNews', 4),
#  ('FILLED', 1),
#  ('@tadbitlooney', 1),
#  ('https://t.co/2Vaaq2Q9QY', 1),
#  ('change', 182),
#  ('@Gunjal_Saheb', 2),
#  ('@graygoods', 1),
#  ('Assembly', 15),
#  ('https://t.co/FyUYqv3jto', 1),
#  ('Pablo.', 1),
#  ('McCrory😴😴', 1),
#  ('@HOA_Bossman', 1),
#  ('CFO', 1),
#  ('https://t.co/QScv50O5Es', 1),
#  ('!........20', 1),
#  ('errors', 2),
#  ('Sheraton', 1),
#  ('#EFPACongress16:', 1),
#  ('@kasie', 1),
#  ('kalin', 1),
#  ('Banning', 7),
#  ('2004', 6),
#  ('@shankarshanmugh', 1),
#  ('bho', 1),
#  ('@Cindy53862027', 1),
#  ('pagla', 2),
#  ('own.', 8),
#  ('https://t.co/nwo3VmD1qQ', 1),
#  ('it..!', 1),
#  ('stock??', 1),
#  ('nacho', 1),
#  ('Rajya', 2),
#  ('Gives', 2),
#  ('upon', 13),
#  ('trickling', 1),
#  ('correctly.', 1),
#  ('altogether', 2),
#  ('aise.', 1),
#  ('https://t.co/di6rNzH3OS', 1),
#  ('आशिष', 1),
#  ('https://t.co/M7WAOGyx36', 1),
#  ('BROKEN', 1),
#  ('damage', 12),
#  ('https://t.co/aGtw15chnb…', 1),
#  ('channel.', 8),
#  ('nope', 1),
#  ('Putin.', 1),
#  ('posing', 1),
#  ('Tried', 3),
#  ('chang', 1),
#  ('ancestors', 1),
#  ('batane', 2),
#  ('use', 106),
#  ('голосов', 1),
#  ('@pr_eq', 1),
#  ('https://t.co/3ra5XpfsWU', 1),
#  ('faith', 13),
#  ('@MrShikaki', 1),
#  ('@casino_whizz', 1),
#  ('DHAN', 2),
#  ('#NeverAgain', 2),
#  ('rules:', 1),
#  ('Assam', 9),
#  ('oversee', 1),
#  ("activist's", 2),
#  ('Truth:', 1),
#  ('Split', 2),
#  ('journalists', 6),
#  ('TORTURED/EATEN', 2),
#  ('https://t.co/eXVxI7RzRu', 1),
#  ('rumors', 1),
#  ('https://t.co/mt8ziZrMAx', 1),
#  ('#Bossip', 1),
#  ('Confusion', 1),
#  ('Reddy…', 1),
#  ('https://t.co/KTeUBrbGiI', 1),
#  ('deputy', 5),
#  ('Awaaz', 1),
#  ('https://t.co/sYwh7mFeeM', 1),
#  ('@svaradarajan', 1),
#  ('underneath', 1),
#  ('Petersburg.', 1),
#  ('trials', 1),
#  ('https://t.co/EFi9ROzOwN', 1),
#  ('midnight.', 1),
#  ('Congratulations.', 1),
#  ('Oklahoma!', 1),
#  ('PMOIndia', 2),
#  ('@derfsamoht', 1),
#  ('@hookjan', 1),
#  ('https://t.co/cTPjTyPsqA', 1),
#  ('@deepdavey', 1),
#  ('ticket!', 1),
#  ('shifting', 1),
#  ('फेरि', 1),
#  ('120+', 1),
#  ('https://t.co/vDIs1IcbU8', 1),
#  ('Secret/SAP', 1),
#  ('Proposed', 1),
#  ('सरदाना', 1),
#  ('✌🏿️😂', 1),
#  ('think...', 1),
#  ('8-9', 1),
#  ('goleyaaa', 4),
#  ('dental', 1),
#  ('Americansunless', 1),
#  ('demographic', 1),
#  ('@LeonKrauze…', 1),
#  ('https://t.co/aAR0upxYLU', 1),
#  ('Kazakhstan', 2),
#  ('bolenge..', 1),
#  ('dekhkar', 1),
#  ('#wasenate', 1),
#  ('https://t.co/HKqmWLsYI4', 1),
#  ('https://t.co/L75xliSsW9', 1),
#  ('Searching', 2),
#  ('Agitation', 1),
#  ('(A', 1),
#  ('202-224-3121', 1),
#  ('HOLOCAUST', 1),
#  ('above', 13),
#  ('Arguably', 1),
#  ('pissing', 4),
#  ('worked', 21),
#  ('firebrand', 1),
#  ('https://t.co/zx84nN80uw', 1),
#  ("p'ganda", 1),
#  ('dust.', 1),
#  ('lower', 13),
#  ('hgsutras', 1),
#  ('https://t.co/ZfxfYIZlLo', 1),
#  ('interstate', 1),
#  ('leak', 1),
#  ('Awaits', 3),
#  ('https://t.co/CNdKbfe69r', 1),
#  ('https://t.co/lzuh08bTh4', 1),
#  ('TV', 25),
#  ('correectly', 1),
#  ('avoiding', 1),
#  ('https://t.co/VYClEvyelj', 1),
#  ('#conkonf', 1),
#  ('@vivatregina', 1),
#  ('آمرانہ', 1),
#  ('Answered', 1),
#  ('@DDNewsHindi', 1),
#  ('Usa', 1),
#  ('#undecidedvoter…', 1),
#  ('examination)', 1),
#  ('local)', 1),
#  ('@sercharlie', 2),
#  ('SenatorBoxer', 1),
#  ('चक्र-व्यू', 1),
#  ('Retweet', 4),
#  ('shortly', 2),
#  ('khushi', 1),
#  ('#Central', 1),
#  ('hai:', 1),
#  ('publish', 1),
#  ('हैं!', 1),
#  ('https://t.co/Jtq8TdoUfR', 1),
#  ('President!.The', 1),
#  ('https://t.co/rn3RM2hp35', 1),
#  ('Rascal', 1),
#  ('https://t.co/TU00XBXNSv…', 1),
#  ('https://t.co/DEyXfiPqyr', 1),
#  ('@DailySignal', 3),
#  ('late...#GoingBlue', 1),
#  ('amru-badalo', 1),
#  ('formed', 2),
#  ('combo', 1),
#  ('yasa', 1),
#  ('Exaggeration.', 1),
#  ('convened', 1),
#  ('aawakat', 1),
#  ('https://t.co/owUiAPE4fU', 1),
#  ('https://t.co/N3QWBzicgo', 1),
#  ('https://t.co/uA3SURA5KF', 1),
#  ('pounce', 1),
#  ('SKAL', 4),
#  ('nepotism', 1),
#  ('mathematics', 1),
#  ('@19141918online', 1),
#  ('Ethernet', 1),
#  ('Vasudeiva', 1),
#  ('horses', 2),
#  ('cards', 6),
#  ('Nah', 4),
#  ('terrorismand', 1),
#  ('@jannarden', 1),
#  ('https://t.co/vOYMGxVCLj', 1),
#  ('(#5)', 1),
#  ('https://t.co/m0MRWAmupl', 1),
#  ('Geek.', 1),
#  ('https://t.co/u6SVozcKR0', 1),
#  ('@pranav_prateek', 1),
#  ('flipping', 1),
#  ('draft', 3),
#  ('Wing', 14),
#  ('exposed', 12),
#  ('#WA07.', 1),
#  ('coins', 18),
#  ('matlab', 2),
#  ('Roz', 1),
#  ('@MrRyanMorrison', 1),
#  ('lawlessness.', 1),
#  ('Ji👏', 1),
#  ('native.', 1),
#  ('@dandonovan_ny', 3),
#  ('further', 10),
#  ('governance', 9),
#  ('workforce.', 1),
#  ('#pk2017', 1),
#  ('BITCH', 2),
#  ('terrible', 9),
#  ('demonizing', 1),
#  ('punishing', 1),
#  ('[India]', 3),
#  ('@1shankarsharma', 2),
#  ('Cursive', 1),
#  ('online', 7),
#  ('twitter&amp;', 1),
#  ('redrawing', 1),
#  ('much.', 9),
#  ('lil', 3),
#  ('शुरु', 2),
#  ('blackmoney', 15),
#  ('Teachers', 1),
#  ('job', 79),
#  ('SecDef', 5),
#  ('https://t.co/Ah7wIwfiWq', 1),
#  ('soninlaw', 1),
#  ('legislation…', 1),
#  ('Nearly', 1),
#  ('Corrupt', 42),
#  ('Times....But', 1),
#  ('@GrdosuGary', 1),
#  ('Hurray!!!', 1),
#  ('https://t.co/UlaKjtdsk0', 1),
#  ('@Waukeshadems', 2),
#  ('@AntLabUCF', 1),
#  ('rules', 24),
#  ('@GulPanag', 3),
#  ("year's", 4),
#  ('toepassingen', 1),
#  ('RBIs', 1),
#  ('https://t.co/nESv9BEyW6', 1),
#  ('#WakeUp', 1),
#  ('Mann', 1),
#  ('@murphtoday', 1),
#  ('@sunilddesai', 1),
#  ('move...', 1),
#  ('https://t.co/leAy4kGul0', 1),
#  ('खाए', 1),
#  ('Goodluck!', 1),
#  ('https://t.co/zG7VGgXWf8', 1),
#  ('weep', 2),
#  ("MN's", 1),
#  ('बढ़', 1),
#  ('oath?', 1),
#  ('Adicha', 1),
#  ('dawn', 2),
#  ('happiest', 1),
#  ('https://t.co/ggJiwyuIqk', 1),
#  ('https://t.co/WuJiusQk6P', 1),
#  ('जीतेगी।', 1),
#  ('less....', 1),
#  ('picture:', 1),
#  ('#Banblackmany', 1),
#  ('linguist;', 1),
#  ('del', 9),
#  ('FACTS', 2),
#  ('https://t.co/ZC0nIzQhmF', 1),
#  ('@TroyPittman1', 1),
#  ('Venkaiah', 100),
#  ('#amen', 1),
#  ('laaega.c…', 1),
#  ('@mjb1994', 1),
#  ('@LiberalJayy', 1),
#  ('Libingan?', 1),
#  ('muh', 4),
#  ('seat.', 3),
#  ('does!', 3),
#  ("Xi's", 1),
#  ('https://t.co/iwXGCBA1Ne', 1),
#  ('https://t.co/scqXp5HUDY', 1),
#  ('Raghuveer...', 1),
#  ("Gore's", 2),
#  ('Vote!', 8),
#  ('horrible.', 1),
#  ('@colnrkurup', 1),
#  ('lion', 1),
#  ('https://t.co/F0RU9Wcp7w', 1),
#  ('nominees.', 1),
#  ('https://t.co/e6J5r0AnP5', 1),
#  ('https://t.co/MmlcsbPERz', 1),
#  ('237', 1),
#  ('years🤔🤔', 1),
#  ('https://t.co/wslup8JhTr', 1),
#  ('channel..only', 1),
#  ('pe', 23),
#  ('@VoteUpstateJobs', 1),
#  ('https://t.co/Mx0r5Ee9r7', 2),
#  ('kabadi', 1),
#  ('https://t.co/A17WfvespP', 1),
#  ("(can't", 1),
#  ('dumbed', 1),
#  ('Makes', 15),
#  ('Consecutive', 1),
#  ('#TFaj', 2),
#  ('SEX-BLACKMAIL', 1),
#  ('congress👍', 1),
#  ('comments', 14),
#  ('blowjob', 2),
#  ('Gareeb', 2),
#  ('#quanticpost', 1),
#  ('@AIIAmericanGirI', 1),
#  ('oficial.', 1),
#  ('باہر', 8),
#  ('urging', 4),
#  ('Napoleonic', 1),
#  ('@4ushashishekhar', 2),
#  ('@StephanieMitz', 1),
#  ('.…', 3),
#  ('coolies', 3),
#  ('@dasraghubar', 1),
#  ('note:', 1),
#  ('#BRA', 1),
#  ('woooow', 1),
#  ('https://t.co/pBIqgSI5GH', 1),
#  ('heard', 27),
#  ('#SangbadPratidin', 1),
#  ('#IndiaAgainstCorruption', 13),
#  ('@DaleF3', 1),
#  ("Here's…", 1),
#  ('RUSSIA.', 1),
#  ('करु', 1),
#  ('Ideas', 1),
#  ('https://t.co/KKnxEMb5Rm', 1),
#  ('https://t.co/J5aICYc086', 1),
#  ('far.', 1),
#  ('samjhe', 1),
#  ('Congress?;', 1),
#  ('supreme?', 1),
#  ('1.ª', 1),
#  ('Football', 3),
#  ('@socraticjuan', 1),
#  ('Trinque', 2),
#  ('deniers', 1),
#  ('tonight.', 12),
#  ('https://t.co/041BUzP9GL', 1),
#  ('https://t.co/9pFD2N3PCN', 1),
#  ('https://t.co/1XyfhYpeUF', 1),
#  ('overrule', 3),
#  ('Thag', 1),
#  ('@amjoyshow', 1),
#  ('suggest', 4),
#  ('Duckworth', 4),
#  ('undedi', 1),
#  ('https://t.co/XtH2P1dk5h', 1),
#  ('ruled', 10),
#  ('@GerryCallahan', 2),
#  ('Truely', 1),
#  ("Z's", 1),
#  ('రాజ్యాంగ', 1),
#  ('https://t.co/2VYpInSK6P', 1),
#  ("Americans'", 1),
#  ('fera', 1),
#  ('https://t.co/35cEgGifEv', 1),
#  ('loser.Reflects', 1),
#  ("'til", 1),
#  ('interventionist', 1),
#  ('#TrumpTrain', 4),
#  ('ASS', 2),
#  ('Nailbiters', 1),
#  ('theory.', 2),
#  ('exactly.', 4),
#  ('@lalahods', 1),
#  ('Septembe…', 1),
#  ('primary', 6),
#  ('@JonahNRO', 1),
#  ('सदावत्सले', 1),
#  ('🙌❤…', 1),
#  ('grt', 1),
#  ('@ChrisVanHollen', 2),
#  ('Jordanian', 2),
#  ('Ji.its', 1),
#  ('https://t.co/niOOAY4J8A', 1),
#  ('bol', 10),
#  ("@realDonaldTrump's", 1),
#  ('shud', 5),
#  ('congress😂.', 1),
#  ('und', 6),
#  ('hay', 1),
#  ('@thenation', 4),
#  ('harvested', 1),
#  ('2-year', 1),
#  ('Spaß', 1),
#  ('Indiana', 5),
#  ('@susanandjohnte1', 1),
#  ('https://t.co/Vhr89416ll', 1),
#  ('Raho.', 1),
#  ('maloom', 1),
#  ('इस', 2),
#  ('painsa..', 1),
#  ('@microassayed', 1),
#  ('#presstitutes', 1),
#  ('@DrGParameshwara…', 1),
#  ('https://t.co/i6XN09Qxi4', 1),
#  ('#sonia', 1),
#  ('already?', 1),
#  ('Mahama', 1),
#  ('@smokeydogg777', 1),
#  ('julab', 1),
#  ('mislead', 2),
#  ('screeching', 1),
#  ('https://t.co/9gT4TVcyBm', 1),
#  ('Wir', 4),
#  ('Sylva', 1),
#  ('https://t.co/6prrwb4fQB', 1),
#  ('electionsis', 1),
#  ('#digitalsignage', 1),
#  ('प्रचार', 4),
#  ('https://t.co/rYwpp1ypHK', 1),
#  ('https://t.co/jdhi0RhXtx', 1),
#  ('https://t.co/X4YLXgZPwK)', 1),
#  ('kuchh', 4),
#  ('Bill:', 3),
#  ('https://t.co/iaybW4qnbP', 1),
#  ('weapons', 2),
#  ('PROTECT', 1),
#  ('https://t.co/lz76dan5R1', 1),
#  ('Cure', 1),
#  ('IssuePoliticsBarack', 1),
#  ('OPPOSITION', 2),
#  ('p-sspoor', 1),
#  ('disregarded', 3),
#  ('ads', 3),
#  ('Adults', 1),
#  ("'moderators';", 1),
#  ('chil…', 1),
#  ('arre', 1),
#  ('guide”', 1),
#  ('torturing', 1),
#  ('spokies', 4),
#  ('https://t.co/wvQCb3gt5J', 1),
#  ('https://t.co/UkcqlzdlZQ', 1),
#  ('meaningfu…', 1),
#  ('asad', 1),
#  ('Surgery', 2),
#  ('atbp./diktador.', 1),
#  ('Prophet', 1),
#  ('#Adelaide', 1),
#  ('consolidate', 1),
#  ('@SamDoesPolitics', 1),
#  ('lybia', 1),
#  ('saval', 1),
#  ('kiaa', 1),
#  ('UNDER', 9),
#  ('Advantages', 1),
#  ("Address'", 1),
#  ('bat', 3),
#  ('dissolute', 1),
#  ('Esthetics', 2),
#  ('wet', 2),
#  ('@Wade4Justice', 1),
#  ('https://t.co/ndWs3DgmgH', 1),
#  ('@phil_oliva', 1),
#  ('Sham', 1),
#  ('@BMswitzerland', 1),
#  ('Rosie', 1),
#  ('Würzburg', 1),
#  ('(Why', 1),
#  ('https://t.co/IzrdW4GmSH', 1),
#  ('inconvenience', 11),
#  ('ROCKS', 1),
#  ('@AC360', 2),
#  ('#development', 1),
#  ('gi.....', 1),
#  ('@agents4policy', 1),
#  ('209th', 1),
#  ('says..Clintons', 1),
#  ('Vote.', 5),
#  ('Shame', 31),
#  ('sworn', 4),
#  ('table.', 1),
#  ('CNNPolitics', 5),
#  ('structures', 1),
#  ('Erzurum', 1),
#  ('.@elianayjohnson', 1),
#  ('EVANS', 1),
#  ('ravaging', 1),
#  ('One-', 1),
#  ('https://t.co/OpZlD7ZjXH', 1),
#  ('http://t.co/7onduz1b3P', 1),
#  ('https://t.co/XN8YHJ52GY', 1),
#  ('minister.', 1),
#  ('https://t.co/ILvaLLe7uB', 1),
#  ('default', 1),
#  ('fas', 1),
#  ('@ramnambiarcc', 2),
#  ('maintain', 7),
#  ('@RealBenCarson', 1),
#  ('Rahul...', 2),
#  ('#DrainHerSwamp', 258),
#  ('Higgins', 2),
#  ('Freedom', 8),
#  ('Songify', 1),
#  ('Franquicia', 1),
#  ('five..Her', 1),
#  ('Motivation…', 1),
#  ('@Bhagi_Rp', 1),
#  ('https://t.co/tXY5tWtFD7', 1),
#  ('@broelman', 1),
#  ('job...', 1),
#  ('#vancouverwa', 1),
#  ('tonight😂', 1),
#  ('@rep.', 1),
#  ('zero', 9),
#  ('BEING', 3),
#  ('https://t.co/U3S0NZ51XW', 1),
#  ('.@Kristian_Jensen:', 1),
#  ('harmful', 4),
#  ('@PMorici1', 1),
#  ('sexual', 4),
#  ('https://t.co/b3O1jJ1w8g', 1),
#  ('#lionheartcrazecontinues', 1),
#  ('📹', 1),
#  ('https://t.co/aQSsPC6dEY', 1),
#  ('Know?', 1),
#  ('exactly', 22),
#  ('gop', 6),
#  ('#129', 1),
#  ('disturb.', 1),
#  ('https://t.co/BakcMMGwPr', 1),
#  ('रोयेगा', 1),
#  ('affiliated', 1),
#  ('@POCRevolution', 1),
#  ('https://t.co/9SRBqICGPO', 1),
#  ('7e58948d-6882-49ed-9420-f243abd1eba4', 1),
#  ('https://t.co/0zbjYtensZ', 1),
#  ('Isliye', 2),
#  ('lady!', 2),
#  ('@Express', 1),
#  ('tampo', 1),
#  ('recruit', 1),
#  ('mushkil', 2),
#  ('NOW-NYC', 1),
#  ('weapon', 1),
#  ('dolt!!', 1),
#  ('https://t.co/WlXFfiwOTr', 1),
#  ('Tweeting', 1),
#  ('15-…', 1),
#  ('https://t.co/ZGzfEcfOTu', 1),
#  ('[14-15', 1),
#  ('Faso', 1),
#  ('https://t.co/OkGFYNg23Z', 1),
#  ('#Rs500', 7),
#  ('@wolfblitzer', 1),
#  ('tiger', 2),
#  ('#Farmers’', 1),
#  ('Abortion', 2),
#  ('debtor.', 1),
#  ('Beavis', 1),
#  ('https://t.co/DiPCUcjf2u', 1),
#  ('portrait', 1),
#  ('bna', 1),
#  ('@VeGeEn', 1),
#  ('sciences', 2),
#  ('https://t.co/KalS0r2nfp', 1),
#  ('@col_nj', 1),
#  ('अपना', 9),
#  ('Access.', 1),
#  ('Caution:', 1),
#  ("l'@EAPCOnlus", 1),
#  ('#future', 1),
#  ('pro-war...', 1),
#  ('https://t.co/mEtUTSyELI', 1),
#  ('abolished', 3),
#  ('@italianirish81', 1),
#  ('SMTF...', 1),
#  ('4m?', 1),
#  ('Softball', 1),
#  ('https://t.co/F5WC6VCiUp', 1),
#  ('jiski', 34),
#  ('@90_Hitler', 1),
#  ('Obama.', 12),
#  ('@BenHowe', 4),
#  ('e079da8f-c7bb-43a7-9cc4-f918de2a503f', 1),
#  ('reaso…', 1),
#  ('connected!', 1),
#  ('https://t.co/6Vb99cGyTU', 1),
#  ('https://t.co/wYWh5QJ5Gd', 1),
#  ('@angelikalagoc', 1),
#  ('Я', 1),
#  ('CHIUCE!', 1),
#  ('party.#IndiaFightsCorruption', 1),
#  ('Dilon', 1),
#  ('https://t.co/m4NJSLWTit', 1),
#  ('expression', 6),
#  ('http://t.co/86v1LGgtpO', 1),
#  ('https://t.co/LNnNfk3WAU', 1),
#  ('staff', 8),
#  ('#Club4Growth', 1),
#  ('https://t.co/zJbKyKOeAw', 1),
#  ("l'appel", 1),
#  ('#Television_Show.', 1),
#  ('victor', 1),
#  ('@tavleen_singh', 1),
#  ('https://t.co/Mn0xYg6fFh', 1),
#  ('Fantasy', 4),
#  ('NY', 16),
#  ('#northdakota', 2),
#  ('milk.', 1),
#  ('https://t.co/jCJETLK37j', 1),
#  ('https://t.co/Pfh68taWXQ', 1),
#  ('factory', 4),
#  ('that…', 3),
#  ('nh', 1),
#  ('bye', 6),
#  ('cruciaal', 1),
#  ('recognize', 3),
#  ('SDN', 1),
#  ('federalism!', 1),
#  ('Congress-i', 1),
#  ('shows.', 1),
#  ('Spokesman', 1),
#  ('adrift', 1),
#  ('@CR', 1),
#  ("dad'", 1),
#  ('@Suren_KK', 1),
#  ('prioritised', 1),
#  ('palpable!!!', 1),
#  ('@PriyankaGandhif', 1),
#  ('mazaak', 1),
#  ('#ClintonCash', 1),
#  ('onward', 1),
#  ('anti-discrimination', 1),
#  ('memo', 1),
#  ('@SenRobPortman', 3),
#  ('#Healey', 1),
#  ('@legalfanatic', 1),
#  ('commercialization', 1),
#  ('Student', 9),
#  ('pathetic', 4),
#  ('@MikaylaNic0le', 1),
#  ('https://t.co/ti3Vl1K7mS', 1),
#  ('Irrigation', 1),
#  ('@Congress', 6),
#  ('🐐.', 1),
#  ('jayanti?', 1),
#  ('https://t.co/h9mkYEQisB', 1),
#  ('VPOTUS', 1),
#  ('Stand', 4),
#  ('Scott', 4),
#  ('https://t.co/jWbF02axEw', 1),
#  ('pants.', 1),
#  ('https://t.co/MQ3R03n6oU', 2),
#  ('again.…', 1),
#  ('https://t.co/5gdoJXTaeb', 1),
#  ('kaabilmunda@gmail.com||', 4),
#  ('Elevation..', 1),
#  ('provide', 6),
#  ('https://t.co/GwBT1IGl3v', 1),
#  ('@Students4Trump8', 1),
#  ('500/-', 6),
#  ('ajib', 1),
#  ('https://t.co/Z8ZXauRwcU', 2),
#  ("mistake'", 1),
#  ('Karnaraka', 1),
#  ('@buzzindelhi', 2),
#  ('https://t.co/NKegXUQcvA', 1),
#  ('#Statecapture', 1),
#  ('this!', 6),
#  ('everything.', 12),
#  ('existence.', 1),
#  ('দিয়াত', 1),
#  ('https://t.co/BtZE7WHv2h', 1),
#  ('https://t.co/AGo1JzBYp8', 1),
#  ('soooooo', 1),
#  ('#pwcnow', 1),
#  ('Starting', 2),
#  ('https://t.co/06sNtAAPYz', 1),
#  ('investigate', 9),
#  ('#INBEDWITHhILLARY', 1),
#  ('work', 211),
#  ('matter!', 1),
#  ('@NaMoKsath', 4),
#  ('https://t.co/Y8eKrqCLNN', 1),
#  ('@yournewswire', 4),
#  ('@FLOTUS', 4),
#  ('P.', 4),
#  ('https://t.co/htzf1alkzz', 1),
#  ('elections.', 22),
#  ('cocktails', 1),
#  ('race.', 5),
#  ('@TheRealMatt___', 1),
#  ('wage', 1),
#  ('@sarkar_swati', 3),
#  ('correction:', 1),
#  ('OF', 115),
#  ('@maffff', 1),
#  ('https://t.co/JXN8OBJ2GP', 1),
#  ('Anyone', 10),
#  ('swimming', 1),
#  ('(Reut...', 2),
#  ('Enlighten', 1),
#  ('@jignesh17007', 1),
#  ('Mukul', 2),
#  ('https://t.co/RSiKi6ANYm', 1),
#  ('isolation', 1),
#  ('political', 106),
#  ('#NewsHour', 2),
#  ('.@usatoday2016', 1),
#  ('Governs', 1),
#  ('@TreyCallaway', 1),
#  ('https://t.co/LkrOglYARC', 1),
#  ('@SrBachchan', 1),
#  ('https://t.co/Mp8rYFSfz1', 1),
#  ('karaigai', 1),
#  ('east', 1),
#  ('@MkWhlr81', 1),
#  ('@Pearce4NM', 1),
#  ('bhaiya', 2),
#  ('DECADE', 1),
#  ('#CONS', 1),
#  ('https://t.co/Y7ACRY6let', 1),
#  ('policy', 34),
#  ('https://t.co/sUvOQkZBmE', 1),
#  ('too...so', 1),
#  ('https://t.co/HAbJVASBcg', 1),
#  ('https://t.co/Ylcdibbpi5', 1),
#  ('6400', 1),
#  ('slap', 7),
#  ('modijee', 2),
#  ('Logic', 1),
#  ('thoughts:', 1),
#  ('paapu', 1),
#  ('World!?', 1),
#  ('yuvaraj', 1),
#  ('AIR', 2),
#  ('https://t.co/d9NIKpFylZ', 1),
#  ...]

# %%
words_tweets = tweets.map(lambda line: len(line.split()))
words_total = words_tweets.reduce(lambda a, b: a+b )
words_total / words_tweets.count()
# Out:
# 10.0294

# %%
word_counts.takeOrdered(10, key=lambda x: -x[1])
# Out:
# [('Congress', 8526),
#  ('the', 6494),
#  ('to', 5829),
#  ('of', 4654),
#  ('for', 3964),
#  ('in', 3794),
#  ('congress', 3675),
#  ('is', 3478),
#  ('and', 3295),
#  ('a', 2985)]

# %% [markdown]
# ## Bigrams
#
# A bigram is combination of two consecutive words.
#
# - Extract the ten most frequent bigrams from the dataset.
#
# Be careful not to consider the last word of a tweet and the first one of the next tweet!
#
# *Hint:* note that the `map` and `flatMap` methods take a **function** as argument, meaning that you can define a function that you pass as argument:
#
# ```python
# def process(line):
#     # Do something
#     return something
#
# x = tweets.flatMap(process)
# ```

# %%
# Your code goes here
def bigram(line):
    bigrams = []
    print(line)
    line = line.split()
    for i, val in enumerate(line):
        if i+1 < len(line):
            bigram = val + '_' + line[i+1]
            bigrams.append(bigram)
    return bigrams

# %%
x = tweets.flatMap(bigram)

# %%
counts_bigrams = x.map(lambda word: (word, 1))
bigram_counts = counts_bigrams.reduceByKey(lambda a, b: a + b)

# %%
bigram_counts.takeOrdered(10, key=lambda x: -x[1])
# Out:
# [('of_Congress', 677),
#  ('of_the', 542),
#  ('Congress_is', 518),
#  ('in_the', 429),
#  ('in_Congress', 410),
#  ('for_Congress', 366),
#  ('vote_for', 357),
#  ('up_for', 344),
#  ('can_do', 305),
#  ('for_grabs', 293)]
